# %%
import pandas as pd

dtypes = {
    'animal_proportion': 'Float32',
    'fao_subgroup_code': 'Int64',
    'has_fish': 'boolean',
    'has_meat_or_poultry': 'boolean',
    'has_seafood': 'boolean',
}

df = pd.read_csv('food_properties.csv',index_col='code', dtype=dtypes)
df.head()
# Out:
#          animal_proportion  fao_subgroup_code  has_fish  has_meat_or_poultry  \
# code
# B93                    1.0                401     False                False
# F000001                0.0               1205     False                False
# F000002                0.0               1205     False                False
# F000003                0.0               1205     False                False
# F000004                1.0               1205     False                False
#
#          has_seafood                                    name
# code
# B93            False  Valio Eila laktoositon kevytmaitojuoma
# F000001        False                                  Sokeri
# F000002        False                           Hedelmäsokeri
# F000003        False                                Siirappi
# F000004        False                                  Hunaja
